# %%
import numpy as np
import pandas as pd
import sklearn
import gc
import os
import re
import math
import sys
import random
from itertools import islice
import time
from scipy.sparse import csr_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import bokeh
import scipy as sp
from scipy import stats
from sklearn.feature_selection import *
import time
from joblib import dump, load
import configparser
import json

from sklearn.decomposition import *
from sklearn.ensemble import *
from collections import Counter
from sklearn.model_selection import *

import lightgbm as lgb
import sklearn.tree as Tr
# Out:
# D:\IDE_Project_Programming\Anaconda\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
from module.module import *
from module.process import *

# %%
seed = 42
DATASET = 0
CONFIGURE_PATH = './conf.ini'

def GetConfigure():
    global PROTEIN_K,RNA_K,ENTROPY_IM,topK,RF_ENSENBLE,TRAIN_TEST_SPLIT
    global cfile,conf,commons
    global PARAMS
    cfile = configparser.ConfigParser()
    cfile.read(CONFIGURE_PATH)
    conf = dict(cfile.items(str(DATASET)))
    commons = dict(cfile.items('common'))

    PROTEIN_K = int( conf[str.lower('PROTEIN_K')] )
    RNA_K = int( conf[str.lower('RNA_K')] )
    ENTROPY_IM = float( conf[str.lower('ENTROPY_IM')] )
    topK = int( conf[str.lower('topK')] )
    RF_ENSENBLE = int( conf[str.lower('RF_ENSENBLE')] )
    TRAIN_TEST_SPLIT = float( commons[str.lower('TRAIN_TEST_SPLIT')] )
    PARAMS = conf['params']
    PARAMS = dict(eval(PARAMS))
    return

GetConfigure()

# %% [markdown]
# #### 读取数据

# %%
def ReadData():
    T=trainer(5,-1)
    data = T.MAIN_SINGLE_TEST(DATASET,PROTEIN_K,RNA_K)
    return data,T

# %% [markdown]
# pair 文件输出

# %%
OutputPairToFile(T.pairs,'./pairs'
                 +str(DATASET)
                 +str(PROTEIN_K)
                 +str(RNA_K)
                 +'.txt')

# %%
def ToMatrix(data,matrix_type='sparse'):
    res = Dict2Sparse(data)
    print('data shape %d %d'%(res[3],res[4]))
    arr = csr_matrix( ( np.array(res[2]),
                 (np.array(res[0]), np.array(res[1])) 
                ), shape = (res[3],res[4]) )
    if matrix_type=='dense':
        arr = arr.todense() ### matrix
        [X,Y] = [np.array(arr),np.array(data[0][1])]
        return [X,Y]
    return arr

# %% [markdown]
# #### 特征选择

# %%
def MutualInformationFeatureSelection(arr,data):
    mi = mutual_info_classif(arr,data[0][1],copy=False,n_neighbors=4)
    select = mi>ENTROPY_IM
    select = np.hstack([select,[False]])
    X = DictionaryToMatrix(data[0][0],data[0][1],feature_num=data[1]+1,select=select)
    Y = np.array(data[0][1])
    print('dimension ratio %f dimension remained %d'
          %(X.shape[1]/(data[1]+1),
            X.shape[1]))
    return [X,Y]

# %% [markdown]
# #### 数据集分割

# %%
def SplitDataset(X,Y):
    X_train, X_test, Y_train, Y_test = \
        train_test_split(X,Y,test_size=TRAIN_TEST_SPLIT,random_state = seed)
    del X,Y
    return [X_train,X_test,Y_train,Y_test]

# %% [markdown]
# #### 二次降维

# %%
def RandomForestDimensionalityReduction(X_train,X_test,Y_train,Y_test):
    rfclf = RandomForestClassifier(n_estimators=RF_ENSENBLE,n_jobs=3)
    rfclf.fit(X_train,Y_train)
    rf_fit_score = rfclf.score(X_train,Y_train)
    print('rf raw data fit score %f'%rf_fit_score)

    rf_select = list(zip([i for i in range(len(rfclf.feature_importances_))],rfclf.feature_importances_))
    rf_select = sorted(rf_select,key=lambda x:x[1],reverse=True)
    rf_select = list(map(lambda x:[x[0],x[1]],rf_select))
    rf_select = np.array(rf_select)

    print('select top K features importances',sum(rf_select[:topK,1]))
    rf_select = rf_select[:topK,0]
    rf_select = rf_select.astype('int32')
    X_train = X_train[:,rf_select]
    X_test = X_test[:,rf_select]
    print('dimension remained %d'%X_train.shape[1])
    return [X_train,X_test,Y_train,Y_test]

# %% [markdown]
# #### 预训练

# %%
def DecisionTreePrefit(X_train,X_test,Y_train,Y_test):
    dtc = Tr.DecisionTreeClassifier()
    dtc.fit(X_train,Y_train)
    print('pre fit score',dtc.score(X_train,Y_train))
    print('pre test score',dtc.score(X_test,Y_test))
    return

# %% [markdown]
# #### LGB

# %%
def LGBTuning(X_train,X_test,Y_train,Y_test):
    params = {
        
            }
    
    clf = lgb.LGBMClassifier()
    
    
    return params

def LGBFit(X_train,X_test,Y_train,Y_test):
    lgb_train = lgb.Dataset(X_train, Y_train)
    lgb_test = lgb.Dataset(X_test, Y_test, reference=lgb_train)

    params = {    
                'boosting_type': 'gbdt',
                'objective': 'binary',
                'metric': 'acc',
                'nthread':6,
#                 'learning_rate':0.08,
                'num_leaves':300, 
                'max_depth': -1,   
                'subsample': 0.9, 
                'colsample_bytree': 0.9, 
                'feature_fraction': 1,
                'bagging_freq': 8,
#                 'num_iterations':300,
                'min_data_in_leaf':2,
                'bagging_fraction': 0.8,
                'num_boost_round':3000,
        
            }

    cv_results = lgb.cv(params, lgb_train, nfold=5  
                        ,stratified=False, shuffle=True
                        ,seed=seed,
                        metrics=['auc','binary_logloss','mae']
                        ,verbose_eval=1)
    print('best n_estimators:', len(cv_results['auc-mean']))
    for k,v in cv_results.items():
        print('best cv score:', k, pd.Series(cv_results[k]).max())
    return [lgb,cv_results]

# lgbclf = lgb.LGBMClassifier(learning_rate=0.045,
#                            max_depth=-1,
#                            objective='binary',
#                             num_leaves=1000,
#                             min_child_samples=10,
#                             n_estimators=1000,
#                             subsample=0.9,
#                             random_state=42
#                            )
# lgbclf.fit(X_train,Y_train)
# print('train',lgbclf.score(X_train,Y_train))
# print('test',lgbclf.score(X_test,Y_test))

# from sklearn.metrics import mean_squared_error
# Y_pred = lgb.predict(X_test, num_iteration=gbm.best_iteration)

# %%
def Pipeline():
    T=trainer(5,-1)
    data = T.MAIN_SINGLE_TEST(DATASET,PROTEIN_K,RNA_K)
    OutputPairToFile(T.pairs,'./pairs'
                     +str(DATASET)
                     +str(PROTEIN_K)
                     +str(RNA_K)
                     +'.txt')
    arr = ToMatrix(data,'sparse')
    [X,Y] = MutualInformationFeatureSelection(arr,data)
    [X_train,X_test,Y_train,Y_test] = SplitDataset(X,Y)
    [X_train,X_test,Y_train,Y_test] = \
        RandomForestDimensionalityReduction(X_train,X_test,Y_train,Y_test)
    DecisionTreePrefit(X_train,X_test,Y_train,Y_test)
    LGBFit(X_train,X_test,Y_train,Y_test)
    return

# %%
def CleanVariables():
    global X,Y
    del X,Y
    return

# %% [markdown]
# #### main

# %%
[data,T] = ReadData()
[X,Y] = ToMatrix(data,'dense')
# Out:
# =============RETRIEVE TRIAN DATA=================
# # DEBUG: # DEBUG: **************new dl 0***************
# # DEBUG: READ SEQ FROM FILE
# # DEBUG: READ CLUSTER FROM FILE
# regex error
# regex error
# # DEBUG: READ PAIR FROM FILE
# read line error
# # DEBUG: GENERATE NEGATIVE PAIR
# # DEBUG: negative pair number 10412
# # DEBUG: PAIR UNION
# # DEBUG: EXTRACT FEATURES--PROTEIN
# # DEBUG: EXTRACT FEATURES--RNA
# # DEBUG: K-MER CALCULATION
# # DEBUG: FEATURE UNION
# # DEBUG: GARBAGE COLLECTION
# MATRIX TRANSFORMATION
# data shape 20824 8984

# %%
[X_train,X_test,Y_train,Y_test] = SplitDataset(X,Y)
[X_train,X_test,Y_train,Y_test] = \
    RandomForestDimensionalityReduction(X_train,X_test,Y_train,Y_test)
# Out:
# rf raw data fit score 1.000000
# select top K features importances 0.9919234054112095
# dimension remained 5000

# %% [markdown]
# #### test

# %%
# DecisionTreePrefit(X_train,X_test,Y_train,Y_test)
[lgb,cv_results] = LGBFit(X_train,X_test,Y_train,Y_test)
WriteResult(DATASET,cv_results,conf,commons)
# Out:
# D:\IDE_Project_Programming\Anaconda\lib\site-packages\lightgbm\engine.py:430: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	cv_agg's auc: 0.917845 + 0.00639071	cv_agg's l1: 0.459686 + 0.000325136	cv_agg's binary_logloss: 0.61687 + 0.000639677
# [2]	cv_agg's auc: 0.931961 + 0.00699863	cv_agg's l1: 0.423644 + 0.000649434	cv_agg's binary_logloss: 0.555004 + 0.00127255
# [3]	cv_agg's auc: 0.94326 + 0.00412542	cv_agg's l1: 0.391311 + 0.000903531	cv_agg's binary_logloss: 0.503749 + 0.00166506
# [4]	cv_agg's auc: 0.950675 + 0.00491033	cv_agg's l1: 0.362194 + 0.000910593	cv_agg's binary_logloss: 0.460539 + 0.0017598
# [5]	cv_agg's auc: 0.953838 + 0.00512886	cv_agg's l1: 0.335813 + 0.00110037	cv_agg's binary_logloss: 0.423701 + 0.00216984
# [6]	cv_agg's auc: 0.956397 + 0.00513443	cv_agg's l1: 0.312264 + 0.00120769	cv_agg's binary_logloss: 0.392683 + 0.00241781
# [7]	cv_agg's auc: 0.95999 + 0.00412227	cv_agg's l1: 0.29097 + 0.0012301	cv_agg's binary_logloss: 0.365853 + 0.00248109
# [8]	cv_agg's auc: 0.962061 + 0.00394526	cv_agg's l1: 0.271798 + 0.00127933	cv_agg's binary_logloss: 0.342737 + 0.00272002
# [9]	cv_agg's auc: 0.968202 + 0.00393207	cv_agg's l1: 0.254213 + 0.00141019	cv_agg's binary_logloss: 0.321228 + 0.00314984
# [10]	cv_agg's auc: 0.968818 + 0.00333611	cv_agg's l1: 0.238423 + 0.00156565	cv_agg's binary_logloss: 0.302803 + 0.00360366
# [11]	cv_agg's auc: 0.969752 + 0.00326494	cv_agg's l1: 0.224105 + 0.00171529	cv_agg's binary_logloss: 0.286754 + 0.00406264
# [12]	cv_agg's auc: 0.969849 + 0.00295474	cv_agg's l1: 0.211056 + 0.00178839	cv_agg's binary_logloss: 0.272956 + 0.00429246
# [13]	cv_agg's auc: 0.9699 + 0.00321245	cv_agg's l1: 0.199198 + 0.00186393	cv_agg's binary_logloss: 0.26082 + 0.004745
# [14]	cv_agg's auc: 0.970806 + 0.00368153	cv_agg's l1: 0.188453 + 0.00205427	cv_agg's binary_logloss: 0.250144 + 0.00536192
# [15]	cv_agg's auc: 0.971598 + 0.00337602	cv_agg's l1: 0.178646 + 0.00200678	cv_agg's binary_logloss: 0.240731 + 0.00526842
# [16]	cv_agg's auc: 0.971925 + 0.00333317	cv_agg's l1: 0.169727 + 0.00210962	cv_agg's binary_logloss: 0.232615 + 0.00566319
# [17]	cv_agg's auc: 0.972372 + 0.00311499	cv_agg's l1: 0.161589 + 0.00220602	cv_agg's binary_logloss: 0.225045 + 0.00589356
# [18]	cv_agg's auc: 0.973043 + 0.00353884	cv_agg's l1: 0.154118 + 0.00229056	cv_agg's binary_logloss: 0.218213 + 0.00622922
# [19]	cv_agg's auc: 0.973496 + 0.00304462	cv_agg's l1: 0.14726 + 0.00229987	cv_agg's binary_logloss: 0.212266 + 0.00649321
# [20]	cv_agg's auc: 0.974008 + 0.00264507	cv_agg's l1: 0.140939 + 0.00236614	cv_agg's binary_logloss: 0.207069 + 0.00683811
# [21]	cv_agg's auc: 0.974504 + 0.00281246	cv_agg's l1: 0.135175 + 0.00245477	cv_agg's binary_logloss: 0.202542 + 0.00720484
# [22]	cv_agg's auc: 0.974894 + 0.00278388	cv_agg's l1: 0.129869 + 0.00244193	cv_agg's binary_logloss: 0.198525 + 0.00735803
# [23]	cv_agg's auc: 0.975104 + 0.00267684	cv_agg's l1: 0.124868 + 0.00241049	cv_agg's binary_logloss: 0.1948 + 0.00740534
# [24]	cv_agg's auc: 0.975181 + 0.00258513	cv_agg's l1: 0.120472 + 0.00243641	cv_agg's binary_logloss: 0.192001 + 0.00769831
# [25]	cv_agg's auc: 0.975831 + 0.00220674	cv_agg's l1: 0.116318 + 0.00244694	cv_agg's binary_logloss: 0.188781 + 0.00783366
# [26]	cv_agg's auc: 0.975995 + 0.00215846	cv_agg's l1: 0.112409 + 0.00249779	cv_agg's binary_logloss: 0.186019 + 0.00809833
# [27]	cv_agg's auc: 0.976283 + 0.00196889	cv_agg's l1: 0.108808 + 0.00240974	cv_agg's binary_logloss: 0.183673 + 0.00803018
# [28]	cv_agg's auc: 0.976395 + 0.00194166	cv_agg's l1: 0.10557 + 0.00238169	cv_agg's binary_logloss: 0.181937 + 0.00800489
# [29]	cv_agg's auc: 0.976649 + 0.00202856	cv_agg's l1: 0.102559 + 0.00231989	cv_agg's binary_logloss: 0.180372 + 0.00808167
# [30]	cv_agg's auc: 0.976854 + 0.00194772	cv_agg's l1: 0.0997526 + 0.00228716	cv_agg's binary_logloss: 0.17901 + 0.00812378
# [31]	cv_agg's auc: 0.977067 + 0.00182367	cv_agg's l1: 0.0971869 + 0.00236691	cv_agg's binary_logloss: 0.177969 + 0.00840762
# [32]	cv_agg's auc: 0.977345 + 0.00176617	cv_agg's l1: 0.0947545 + 0.00237476	cv_agg's binary_logloss: 0.177094 + 0.00856371
# [33]	cv_agg's auc: 0.977665 + 0.00160412	cv_agg's l1: 0.0926576 + 0.00231592	cv_agg's binary_logloss: 0.17616 + 0.00875491
# [34]	cv_agg's auc: 0.977867 + 0.00156661	cv_agg's l1: 0.0907467 + 0.00230448	cv_agg's binary_logloss: 0.175471 + 0.0091649
# [35]	cv_agg's auc: 0.97798 + 0.00158049	cv_agg's l1: 0.088957 + 0.00229133	cv_agg's binary_logloss: 0.175141 + 0.00943232
# [36]	cv_agg's auc: 0.978035 + 0.00154878	cv_agg's l1: 0.0872176 + 0.00233227	cv_agg's binary_logloss: 0.174857 + 0.00964486
# [37]	cv_agg's auc: 0.978194 + 0.00147551	cv_agg's l1: 0.0855031 + 0.00242789	cv_agg's binary_logloss: 0.174397 + 0.00996387
# [38]	cv_agg's auc: 0.978312 + 0.00126768	cv_agg's l1: 0.0839637 + 0.00238755	cv_agg's binary_logloss: 0.174193 + 0.00974445
# [39]	cv_agg's auc: 0.978554 + 0.00117274	cv_agg's l1: 0.0825455 + 0.00233848	cv_agg's binary_logloss: 0.174019 + 0.00988636
# [40]	cv_agg's auc: 0.978632 + 0.00121479	cv_agg's l1: 0.081234 + 0.00239939	cv_agg's binary_logloss: 0.174302 + 0.0102072
# [41]	cv_agg's auc: 0.978741 + 0.00123328	cv_agg's l1: 0.0799893 + 0.00245065	cv_agg's binary_logloss: 0.174322 + 0.0105018
# [42]	cv_agg's auc: 0.97891 + 0.00128278	cv_agg's l1: 0.0787912 + 0.00255141	cv_agg's binary_logloss: 0.174272 + 0.0108325
# [43]	cv_agg's auc: 0.97899 + 0.00132482	cv_agg's l1: 0.0776975 + 0.00264372	cv_agg's binary_logloss: 0.174564 + 0.0112067
# [44]	cv_agg's auc: 0.979036 + 0.00131475	cv_agg's l1: 0.0766624 + 0.00268435	cv_agg's binary_logloss: 0.174882 + 0.0113776
# [45]	cv_agg's auc: 0.979239 + 0.00137072	cv_agg's l1: 0.0756716 + 0.00279916	cv_agg's binary_logloss: 0.175077 + 0.011825
# [46]	cv_agg's auc: 0.979338 + 0.00137637	cv_agg's l1: 0.0747026 + 0.0028568	cv_agg's binary_logloss: 0.1754 + 0.0121387
# [47]	cv_agg's auc: 0.979494 + 0.00142917	cv_agg's l1: 0.0737819 + 0.00289096	cv_agg's binary_logloss: 0.175699 + 0.0124408
# [48]	cv_agg's auc: 0.979585 + 0.00142487	cv_agg's l1: 0.0729747 + 0.00292847	cv_agg's binary_logloss: 0.176214 + 0.0127842
# [49]	cv_agg's auc: 0.979827 + 0.00146122	cv_agg's l1: 0.0722201 + 0.0029431	cv_agg's binary_logloss: 0.176218 + 0.0129482
# [50]	cv_agg's auc: 0.980031 + 0.00133524	cv_agg's l1: 0.0716078 + 0.00303413	cv_agg's binary_logloss: 0.176492 + 0.0130373
# [51]	cv_agg's auc: 0.98023 + 0.0012623	cv_agg's l1: 0.0709741 + 0.00312826	cv_agg's binary_logloss: 0.1767 + 0.0130589
# [52]	cv_agg's auc: 0.980418 + 0.00123001	cv_agg's l1: 0.0703407 + 0.00315213	cv_agg's binary_logloss: 0.17688 + 0.0133218
# [53]	cv_agg's auc: 0.980517 + 0.00117931	cv_agg's l1: 0.0697537 + 0.00316566	cv_agg's binary_logloss: 0.177356 + 0.0132634
# [54]	cv_agg's auc: 0.980591 + 0.00114579	cv_agg's l1: 0.0692097 + 0.00317665	cv_agg's binary_logloss: 0.177843 + 0.0133082
# [55]	cv_agg's auc: 0.980643 + 0.00111135	cv_agg's l1: 0.0686774 + 0.00317945	cv_agg's binary_logloss: 0.178516 + 0.0133905
# [56]	cv_agg's auc: 0.980761 + 0.0010167	cv_agg's l1: 0.0680768 + 0.00326342	cv_agg's binary_logloss: 0.178929 + 0.0133311
# [57]	cv_agg's auc: 0.98086 + 0.0010178	cv_agg's l1: 0.0676127 + 0.0032668	cv_agg's binary_logloss: 0.179286 + 0.0133231
# [58]	cv_agg's auc: 0.980931 + 0.00102837	cv_agg's l1: 0.0671612 + 0.00321925	cv_agg's binary_logloss: 0.179964 + 0.0133637
# [59]	cv_agg's auc: 0.980994 + 0.00102258	cv_agg's l1: 0.0667067 + 0.003164	cv_agg's binary_logloss: 0.180607 + 0.0134483
# [60]	cv_agg's auc: 0.981053 + 0.0010445	cv_agg's l1: 0.0662631 + 0.00317666	cv_agg's binary_logloss: 0.181193 + 0.013587
# [61]	cv_agg's auc: 0.981143 + 0.00100451	cv_agg's l1: 0.0658913 + 0.00317675	cv_agg's binary_logloss: 0.181812 + 0.0135433
# [62]	cv_agg's auc: 0.981212 + 0.00106214	cv_agg's l1: 0.0654847 + 0.00319011	cv_agg's binary_logloss: 0.182579 + 0.0138198
# [63]	cv_agg's auc: 0.981242 + 0.00106316	cv_agg's l1: 0.0651239 + 0.00320087	cv_agg's binary_logloss: 0.183259 + 0.013907
# [64]	cv_agg's auc: 0.981331 + 0.00108911	cv_agg's l1: 0.0647842 + 0.003203	cv_agg's binary_logloss: 0.184171 + 0.014008
# [65]	cv_agg's auc: 0.981334 + 0.0010951	cv_agg's l1: 0.0644384 + 0.00322021	cv_agg's binary_logloss: 0.184988 + 0.0142374
# [66]	cv_agg's auc: 0.981424 + 0.00113006	cv_agg's l1: 0.0640794 + 0.00324641	cv_agg's binary_logloss: 0.185432 + 0.0143744
# [67]	cv_agg's auc: 0.981473 + 0.00118854	cv_agg's l1: 0.0637423 + 0.00326478	cv_agg's binary_logloss: 0.186088 + 0.014653
# [68]	cv_agg's auc: 0.981567 + 0.00117157	cv_agg's l1: 0.0634595 + 0.00324523	cv_agg's binary_logloss: 0.186771 + 0.0146773
# [69]	cv_agg's auc: 0.981587 + 0.00117821	cv_agg's l1: 0.0631732 + 0.00326369	cv_agg's binary_logloss: 0.187612 + 0.0147405
# [70]	cv_agg's auc: 0.981618 + 0.00121399	cv_agg's l1: 0.0628488 + 0.00329367	cv_agg's binary_logloss: 0.18824 + 0.0151127
# [71]	cv_agg's auc: 0.98166 + 0.00121916	cv_agg's l1: 0.0625322 + 0.00330129	cv_agg's binary_logloss: 0.18887 + 0.0151711
# [72]	cv_agg's auc: 0.981795 + 0.00123399	cv_agg's l1: 0.0622347 + 0.00328941	cv_agg's binary_logloss: 0.189384 + 0.0152783
# [73]	cv_agg's auc: 0.981597 + 0.0010466	cv_agg's l1: 0.0620396 + 0.0032885	cv_agg's binary_logloss: 0.191799 + 0.0146162
# [74]	cv_agg's auc: 0.981746 + 0.00103736	cv_agg's l1: 0.0616974 + 0.0033816	cv_agg's binary_logloss: 0.192051 + 0.0147861
# [75]	cv_agg's auc: 0.981742 + 0.00104692	cv_agg's l1: 0.0615133 + 0.00339667	cv_agg's binary_logloss: 0.192939 + 0.0148283
# [76]	cv_agg's auc: 0.981833 + 0.00104827	cv_agg's l1: 0.0612703 + 0.00344007	cv_agg's binary_logloss: 0.193553 + 0.0148993
# [77]	cv_agg's auc: 0.981898 + 0.00102889	cv_agg's l1: 0.0610615 + 0.00347776	cv_agg's binary_logloss: 0.194253 + 0.0148143
# [78]	cv_agg's auc: 0.981963 + 0.00105047	cv_agg's l1: 0.0608885 + 0.00351954	cv_agg's binary_logloss: 0.194962 + 0.0149974
# [79]	cv_agg's auc: 0.982058 + 0.00106362	cv_agg's l1: 0.0607029 + 0.00356245	cv_agg's binary_logloss: 0.195571 + 0.0151213
# [80]	cv_agg's auc: 0.982138 + 0.00101673	cv_agg's l1: 0.0604844 + 0.00357894	cv_agg's binary_logloss: 0.196153 + 0.0149871
# [81]	cv_agg's auc: 0.98219 + 0.00101883	cv_agg's l1: 0.0602559 + 0.00355709	cv_agg's binary_logloss: 0.196731 + 0.0150929
# [82]	cv_agg's auc: 0.982266 + 0.00103846	cv_agg's l1: 0.0600678 + 0.00358027	cv_agg's binary_logloss: 0.197493 + 0.0152896
# [83]	cv_agg's auc: 0.982261 + 0.00101758	cv_agg's l1: 0.0599266 + 0.00360317	cv_agg's binary_logloss: 0.198534 + 0.0153345
# [84]	cv_agg's auc: 0.982295 + 0.00108321	cv_agg's l1: 0.0597308 + 0.00363072	cv_agg's binary_logloss: 0.199304 + 0.0156854
# [85]	cv_agg's auc: 0.982335 + 0.00109098	cv_agg's l1: 0.0595437 + 0.00362899	cv_agg's binary_logloss: 0.20011 + 0.0156807
# [86]	cv_agg's auc: 0.982377 + 0.00109933	cv_agg's l1: 0.0593377 + 0.00366888	cv_agg's binary_logloss: 0.200878 + 0.0158699
# [87]	cv_agg's auc: 0.982415 + 0.00109128	cv_agg's l1: 0.0591914 + 0.00367806	cv_agg's binary_logloss: 0.201934 + 0.0159826
# [88]	cv_agg's auc: 0.982432 + 0.00108541	cv_agg's l1: 0.0590153 + 0.00369795	cv_agg's binary_logloss: 0.203072 + 0.0162521
# [89]	cv_agg's auc: 0.982506 + 0.00105875	cv_agg's l1: 0.0588052 + 0.00371882	cv_agg's binary_logloss: 0.203771 + 0.0163116
# [90]	cv_agg's auc: 0.98257 + 0.00110989	cv_agg's l1: 0.0586109 + 0.00374892	cv_agg's binary_logloss: 0.204406 + 0.0163765
# [91]	cv_agg's auc: 0.982597 + 0.00107537	cv_agg's l1: 0.0584383 + 0.00376769	cv_agg's binary_logloss: 0.205082 + 0.0162771
# [92]	cv_agg's auc: 0.98265 + 0.00107932	cv_agg's l1: 0.0582984 + 0.00384519	cv_agg's binary_logloss: 0.205938 + 0.0164136
# [93]	cv_agg's auc: 0.982678 + 0.00104683	cv_agg's l1: 0.0581466 + 0.0038539	cv_agg's binary_logloss: 0.206793 + 0.0165279
# [94]	cv_agg's auc: 0.982682 + 0.00107174	cv_agg's l1: 0.0579966 + 0.00392468	cv_agg's binary_logloss: 0.207702 + 0.016759
# [95]	cv_agg's auc: 0.982702 + 0.0010592	cv_agg's l1: 0.0578788 + 0.00397009	cv_agg's binary_logloss: 0.208802 + 0.0170066
# [96]	cv_agg's auc: 0.982708 + 0.00107287	cv_agg's l1: 0.0577575 + 0.0039623	cv_agg's binary_logloss: 0.209963 + 0.0171826
# [97]	cv_agg's auc: 0.982786 + 0.00108159	cv_agg's l1: 0.057624 + 0.00397366	cv_agg's binary_logloss: 0.210462 + 0.0172881
# [98]	cv_agg's auc: 0.982812 + 0.00105861	cv_agg's l1: 0.0574701 + 0.00400757	cv_agg's binary_logloss: 0.211094 + 0.0173529
# [99]	cv_agg's auc: 0.982919 + 0.00103943	cv_agg's l1: 0.0573285 + 0.00402359	cv_agg's binary_logloss: 0.211622 + 0.0173353
# [100]	cv_agg's auc: 0.982913 + 0.00104965	cv_agg's l1: 0.05719 + 0.0040659	cv_agg's binary_logloss: 0.212456 + 0.0174877
# [101]	cv_agg's auc: 0.982948 + 0.00104949	cv_agg's l1: 0.0570528 + 0.0040869	cv_agg's binary_logloss: 0.213232 + 0.0177119
# [102]	cv_agg's auc: 0.982981 + 0.00102769	cv_agg's l1: 0.0569106 + 0.00408101	cv_agg's binary_logloss: 0.21399 + 0.0175799
# [103]	cv_agg's auc: 0.98301 + 0.00101973	cv_agg's l1: 0.0568056 + 0.0040983	cv_agg's binary_logloss: 0.214941 + 0.0177113
# [104]	cv_agg's auc: 0.983024 + 0.00102809	cv_agg's l1: 0.0566563 + 0.00414742	cv_agg's binary_logloss: 0.215737 + 0.0176499
# [105]	cv_agg's auc: 0.983035 + 0.00101949	cv_agg's l1: 0.0565486 + 0.00418811	cv_agg's binary_logloss: 0.216694 + 0.0179075
# [106]	cv_agg's auc: 0.983074 + 0.00101179	cv_agg's l1: 0.0564187 + 0.00423708	cv_agg's binary_logloss: 0.217391 + 0.0179402
# [107]	cv_agg's auc: 0.983072 + 0.000982645	cv_agg's l1: 0.0563371 + 0.00426933	cv_agg's binary_logloss: 0.218321 + 0.0182137
# [108]	cv_agg's auc: 0.98301 + 0.000960173	cv_agg's l1: 0.0562636 + 0.00430619	cv_agg's binary_logloss: 0.219486 + 0.0184902
# [109]	cv_agg's auc: 0.983035 + 0.000990696	cv_agg's l1: 0.0561746 + 0.00431809	cv_agg's binary_logloss: 0.220287 + 0.0188258
# [110]	cv_agg's auc: 0.983059 + 0.000973005	cv_agg's l1: 0.0560653 + 0.00434382	cv_agg's binary_logloss: 0.221235 + 0.0190512
# [111]	cv_agg's auc: 0.983102 + 0.000981565	cv_agg's l1: 0.05598 + 0.00434748	cv_agg's binary_logloss: 0.222158 + 0.0192358
# [112]	cv_agg's auc: 0.983122 + 0.000984326	cv_agg's l1: 0.0558688 + 0.0043724	cv_agg's binary_logloss: 0.22313 + 0.0194229
# [113]	cv_agg's auc: 0.983176 + 0.00100261	cv_agg's l1: 0.055744 + 0.004374	cv_agg's binary_logloss: 0.223799 + 0.0196434
# [114]	cv_agg's auc: 0.983164 + 0.00104287	cv_agg's l1: 0.0556512 + 0.00436514	cv_agg's binary_logloss: 0.224723 + 0.0198849
# [115]	cv_agg's auc: 0.983167 + 0.00105086	cv_agg's l1: 0.0555992 + 0.00437853	cv_agg's binary_logloss: 0.225783 + 0.0200061
# [116]	cv_agg's auc: 0.983155 + 0.00109518	cv_agg's l1: 0.0555004 + 0.00436513	cv_agg's binary_logloss: 0.22683 + 0.0202639
# [117]	cv_agg's auc: 0.983165 + 0.00108303	cv_agg's l1: 0.0553956 + 0.00438412	cv_agg's binary_logloss: 0.227654 + 0.0203798
# [118]	cv_agg's auc: 0.983184 + 0.00108717	cv_agg's l1: 0.0552803 + 0.00439904	cv_agg's binary_logloss: 0.228495 + 0.0202542
# [119]	cv_agg's auc: 0.983139 + 0.00110158	cv_agg's l1: 0.0552277 + 0.00441493	cv_agg's binary_logloss: 0.229774 + 0.020503
# [120]	cv_agg's auc: 0.983195 + 0.00111832	cv_agg's l1: 0.055134 + 0.00437838	cv_agg's binary_logloss: 0.230684 + 0.0207041
# [121]	cv_agg's auc: 0.983232 + 0.00114712	cv_agg's l1: 0.0550559 + 0.0043442	cv_agg's binary_logloss: 0.231426 + 0.0205672
# [122]	cv_agg's auc: 0.983256 + 0.00111837	cv_agg's l1: 0.0549489 + 0.00435907	cv_agg's binary_logloss: 0.232044 + 0.0205417
# [123]	cv_agg's auc: 0.983273 + 0.00112633	cv_agg's l1: 0.0548273 + 0.0043242	cv_agg's binary_logloss: 0.232855 + 0.0205433
# [124]	cv_agg's auc: 0.983324 + 0.00112005	cv_agg's l1: 0.054742 + 0.00431366	cv_agg's binary_logloss: 0.233586 + 0.0205386
# [125]	cv_agg's auc: 0.983326 + 0.00113674	cv_agg's l1: 0.0546431 + 0.00427624	cv_agg's binary_logloss: 0.234385 + 0.0207433
# [126]	cv_agg's auc: 0.983353 + 0.00113032	cv_agg's l1: 0.0545705 + 0.00428223	cv_agg's binary_logloss: 0.235311 + 0.0210278
# [127]	cv_agg's auc: 0.983344 + 0.00108498	cv_agg's l1: 0.0545308 + 0.00425776	cv_agg's binary_logloss: 0.236349 + 0.0208599
# [128]	cv_agg's auc: 0.983354 + 0.00104247	cv_agg's l1: 0.0544808 + 0.00427286	cv_agg's binary_logloss: 0.237315 + 0.0210376
# [129]	cv_agg's auc: 0.983381 + 0.00105199	cv_agg's l1: 0.0544021 + 0.00422684	cv_agg's binary_logloss: 0.23812 + 0.0210289
# [130]	cv_agg's auc: 0.983383 + 0.00102957	cv_agg's l1: 0.0542977 + 0.00422289	cv_agg's binary_logloss: 0.238965 + 0.0210154
# [131]	cv_agg's auc: 0.98339 + 0.00102425	cv_agg's l1: 0.0542103 + 0.00421479	cv_agg's binary_logloss: 0.239816 + 0.0210245
# [132]	cv_agg's auc: 0.983423 + 0.00103231	cv_agg's l1: 0.0541381 + 0.00422463	cv_agg's binary_logloss: 0.240628 + 0.0210172
# [133]	cv_agg's auc: 0.98344 + 0.00100772	cv_agg's l1: 0.0540694 + 0.00420874	cv_agg's binary_logloss: 0.241624 + 0.0210438
# [134]	cv_agg's auc: 0.983433 + 0.000979383	cv_agg's l1: 0.0540305 + 0.00420363	cv_agg's binary_logloss: 0.242724 + 0.0210177
# [135]	cv_agg's auc: 0.983458 + 0.00095534	cv_agg's l1: 0.0539656 + 0.00416088	cv_agg's binary_logloss: 0.243689 + 0.0207307
# [136]	cv_agg's auc: 0.983442 + 0.000983641	cv_agg's l1: 0.0539256 + 0.00417579	cv_agg's binary_logloss: 0.244857 + 0.0208983
# [137]	cv_agg's auc: 0.983443 + 0.000950379	cv_agg's l1: 0.0538125 + 0.00420079	cv_agg's binary_logloss: 0.2458 + 0.0210234
# [138]	cv_agg's auc: 0.983458 + 0.000937996	cv_agg's l1: 0.0537526 + 0.0042052	cv_agg's binary_logloss: 0.246694 + 0.0211023
# [139]	cv_agg's auc: 0.98348 + 0.000938857	cv_agg's l1: 0.0536829 + 0.00423356	cv_agg's binary_logloss: 0.247525 + 0.0213286
# [140]	cv_agg's auc: 0.983484 + 0.000954016	cv_agg's l1: 0.0536172 + 0.00421372	cv_agg's binary_logloss: 0.248534 + 0.0213436
# [141]	cv_agg's auc: 0.983501 + 0.000944661	cv_agg's l1: 0.0535634 + 0.00420958	cv_agg's binary_logloss: 0.249626 + 0.0213948
# [142]	cv_agg's auc: 0.983515 + 0.000918638	cv_agg's l1: 0.0534996 + 0.00422235	cv_agg's binary_logloss: 0.25067 + 0.0214303
# [143]	cv_agg's auc: 0.983541 + 0.000918634	cv_agg's l1: 0.0534135 + 0.00420856	cv_agg's binary_logloss: 0.251455 + 0.0215698
# [144]	cv_agg's auc: 0.983583 + 0.00093211	cv_agg's l1: 0.053373 + 0.00421061	cv_agg's binary_logloss: 0.252314 + 0.0217383
# [145]	cv_agg's auc: 0.983652 + 0.000888172	cv_agg's l1: 0.0533545 + 0.00422757	cv_agg's binary_logloss: 0.253026 + 0.0219161
# [146]	cv_agg's auc: 0.983668 + 0.000871773	cv_agg's l1: 0.0532819 + 0.00428231	cv_agg's binary_logloss: 0.253825 + 0.0221053
# [147]	cv_agg's auc: 0.983674 + 0.000876023	cv_agg's l1: 0.0532777 + 0.00429911	cv_agg's binary_logloss: 0.254738 + 0.0222713
# [148]	cv_agg's auc: 0.983671 + 0.000870643	cv_agg's l1: 0.0532616 + 0.00432419	cv_agg's binary_logloss: 0.255683 + 0.0224406
# [149]	cv_agg's auc: 0.983692 + 0.000882427	cv_agg's l1: 0.0531941 + 0.00434835	cv_agg's binary_logloss: 0.256511 + 0.0227962
# [150]	cv_agg's auc: 0.983733 + 0.000855091	cv_agg's l1: 0.0531365 + 0.00436062	cv_agg's binary_logloss: 0.257382 + 0.0227754
# [151]	cv_agg's auc: 0.983716 + 0.000854288	cv_agg's l1: 0.0530826 + 0.00436477	cv_agg's binary_logloss: 0.258449 + 0.0229055
# [152]	cv_agg's auc: 0.983716 + 0.000814241	cv_agg's l1: 0.0530433 + 0.00433901	cv_agg's binary_logloss: 0.259431 + 0.0228424
# [153]	cv_agg's auc: 0.983706 + 0.000809351	cv_agg's l1: 0.0530026 + 0.0043509	cv_agg's binary_logloss: 0.260209 + 0.0229963
# [154]	cv_agg's auc: 0.983714 + 0.000820626	cv_agg's l1: 0.0529889 + 0.00436367	cv_agg's binary_logloss: 0.26111 + 0.0232801
# [155]	cv_agg's auc: 0.983749 + 0.000801842	cv_agg's l1: 0.052952 + 0.00439042	cv_agg's binary_logloss: 0.26184 + 0.0234336
# [156]	cv_agg's auc: 0.983749 + 0.000788929	cv_agg's l1: 0.0529083 + 0.00439013	cv_agg's binary_logloss: 0.262734 + 0.0235518
# [157]	cv_agg's auc: 0.983757 + 0.000793682	cv_agg's l1: 0.0528649 + 0.00441008	cv_agg's binary_logloss: 0.263598 + 0.0238608
# [158]	cv_agg's auc: 0.983764 + 0.000763899	cv_agg's l1: 0.0528188 + 0.00441441	cv_agg's binary_logloss: 0.264408 + 0.02384
# [159]	cv_agg's auc: 0.983764 + 0.000760591	cv_agg's l1: 0.0528076 + 0.00442201	cv_agg's binary_logloss: 0.265351 + 0.0240722
# [160]	cv_agg's auc: 0.983739 + 0.000761358	cv_agg's l1: 0.0527835 + 0.00441912	cv_agg's binary_logloss: 0.26635 + 0.0241063
# [161]	cv_agg's auc: 0.983767 + 0.000781457	cv_agg's l1: 0.0527375 + 0.00443795	cv_agg's binary_logloss: 0.26695 + 0.0243041
# [162]	cv_agg's auc: 0.983777 + 0.000786571	cv_agg's l1: 0.0527392 + 0.00443709	cv_agg's binary_logloss: 0.267696 + 0.0243901
# [163]	cv_agg's auc: 0.983809 + 0.000793917	cv_agg's l1: 0.052714 + 0.00442605	cv_agg's binary_logloss: 0.268266 + 0.0244489
# [164]	cv_agg's auc: 0.983838 + 0.000797457	cv_agg's l1: 0.0526808 + 0.00443582	cv_agg's binary_logloss: 0.268905 + 0.0244754
# [165]	cv_agg's auc: 0.98383 + 0.000790127	cv_agg's l1: 0.0526709 + 0.00442639	cv_agg's binary_logloss: 0.269704 + 0.024681
# [166]	cv_agg's auc: 0.98385 + 0.000775504	cv_agg's l1: 0.052625 + 0.00446035	cv_agg's binary_logloss: 0.270304 + 0.0247779
# [167]	cv_agg's auc: 0.98384 + 0.000791234	cv_agg's l1: 0.0526188 + 0.00446993	cv_agg's binary_logloss: 0.271179 + 0.0250315
# [168]	cv_agg's auc: 0.983864 + 0.00079022	cv_agg's l1: 0.052579 + 0.00446233	cv_agg's binary_logloss: 0.271789 + 0.0251616
# [169]	cv_agg's auc: 0.983897 + 0.000780492	cv_agg's l1: 0.0525204 + 0.00445478	cv_agg's binary_logloss: 0.272327 + 0.0250879
# [170]	cv_agg's auc: 0.983908 + 0.000773024	cv_agg's l1: 0.0524812 + 0.004458	cv_agg's binary_logloss: 0.272813 + 0.0251686
# [171]	cv_agg's auc: 0.983913 + 0.000739523	cv_agg's l1: 0.0524401 + 0.00445018	cv_agg's binary_logloss: 0.273486 + 0.0250782
# [172]	cv_agg's auc: 0.983922 + 0.000744175	cv_agg's l1: 0.0524283 + 0.00444488	cv_agg's binary_logloss: 0.274115 + 0.025089
# [173]	cv_agg's auc: 0.98392 + 0.000746852	cv_agg's l1: 0.0523728 + 0.00444773	cv_agg's binary_logloss: 0.274726 + 0.025212
# [174]	cv_agg's auc: 0.983928 + 0.000766079	cv_agg's l1: 0.0523508 + 0.00444293	cv_agg's binary_logloss: 0.275374 + 0.0251833
# [175]	cv_agg's auc: 0.98393 + 0.000752132	cv_agg's l1: 0.0523221 + 0.00442692	cv_agg's binary_logloss: 0.276155 + 0.0250921
# [176]	cv_agg's auc: 0.983924 + 0.000732083	cv_agg's l1: 0.052248 + 0.00445882	cv_agg's binary_logloss: 0.276679 + 0.0252272
# [177]	cv_agg's auc: 0.983763 + 0.00079193	cv_agg's l1: 0.0522453 + 0.00439893	cv_agg's binary_logloss: 0.279385 + 0.0241304
# [178]	cv_agg's auc: 0.979669 + 0.00623138	cv_agg's l1: 0.0541596 + 0.00596643	cv_agg's binary_logloss: 0.354481 + 0.114578
# [179]	cv_agg's auc: 0.974663 + 0.0145252	cv_agg's l1: 0.0565286 + 0.00886341	cv_agg's binary_logloss: 0.442493 + 0.254921
# [180]	cv_agg's auc: 0.964825 + 0.0247784	cv_agg's l1: 0.0617064 + 0.0149639	cv_agg's binary_logloss: 0.628873 + 0.459044
# [181]	cv_agg's auc: 0.929887 + 0.0844474	cv_agg's l1: 0.0821898 + 0.0494205	cv_agg's binary_logloss: 1.41529 + 1.82618
# [182]	cv_agg's auc: 0.878345 + 0.155153	cv_agg's l1: 0.12307 + 0.112311	cv_agg's binary_logloss: 2.97283 + 4.19805
# [183]	cv_agg's auc: 0.891664 + 0.134325	cv_agg's l1: 0.13194 + 0.132166	cv_agg's binary_logloss: 3.40594 + 5.096
# [184]	cv_agg's auc: 0.868906 + 0.14168	cv_agg's l1: 0.160452 + 0.144314	cv_agg's binary_logloss: 4.4822 + 5.53464
# [185]	cv_agg's auc: 0.862684 + 0.149115	cv_agg's l1: 0.168162 + 0.146062	cv_agg's binary_logloss: 4.8299 + 5.63362
# [186]	cv_agg's auc: 0.834081 + 0.186389	cv_agg's l1: 0.197624 + 0.181575	cv_agg's binary_logloss: 5.93299 + 6.94997
# [187]	cv_agg's auc: 0.84677 + 0.170576	cv_agg's l1: 0.201658 + 0.186826	cv_agg's binary_logloss: 6.09542 + 7.15479
# [188]	cv_agg's auc: 0.832784 + 0.191814	cv_agg's l1: 0.207154 + 0.19448	cv_agg's binary_logloss: 6.28652 + 7.41595
# [189]	cv_agg's auc: 0.83299 + 0.191449	cv_agg's l1: 0.207281 + 0.194697	cv_agg's binary_logloss: 6.29184 + 7.42264
# [190]	cv_agg's auc: 0.832992 + 0.19145	cv_agg's l1: 0.207265 + 0.19471	cv_agg's binary_logloss: 6.29209 + 7.42243
# [191]	cv_agg's auc: 0.832987 + 0.191446	cv_agg's l1: 0.207243 + 0.194728	cv_agg's binary_logloss: 6.2924 + 7.42218
# [192]	cv_agg's auc: 0.832983 + 0.191443	cv_agg's l1: 0.20723 + 0.194739	cv_agg's binary_logloss: 6.29266 + 7.42196
# [193]	cv_agg's auc: 0.832978 + 0.191439	cv_agg's l1: 0.207212 + 0.194754	cv_agg's binary_logloss: 6.29299 + 7.4217
# [194]	cv_agg's auc: 0.832993 + 0.191451	cv_agg's l1: 0.207182 + 0.194777	cv_agg's binary_logloss: 6.29323 + 7.4215
# [195]	cv_agg's auc: 0.832988 + 0.191447	cv_agg's l1: 0.207162 + 0.194793	cv_agg's binary_logloss: 6.29357 + 7.42123
# [196]	cv_agg's auc: 0.832976 + 0.191438	cv_agg's l1: 0.207143 + 0.194809	cv_agg's binary_logloss: 6.29386 + 7.42099
# [197]	cv_agg's auc: 0.832969 + 0.191432	cv_agg's l1: 0.207142 + 0.19481	cv_agg's binary_logloss: 6.29416 + 7.42075
# [198]	cv_agg's auc: 0.832967 + 0.191431	cv_agg's l1: 0.207127 + 0.194822	cv_agg's binary_logloss: 6.2945 + 7.42047
# [199]	cv_agg's auc: 0.832963 + 0.191427	cv_agg's l1: 0.207115 + 0.194832	cv_agg's binary_logloss: 6.29481 + 7.42022
# [200]	cv_agg's auc: 0.832968 + 0.191431	cv_agg's l1: 0.207119 + 0.19483	cv_agg's binary_logloss: 6.29515 + 7.41995
# [201]	cv_agg's auc: 0.832965 + 0.191429	cv_agg's l1: 0.207107 + 0.194839	cv_agg's binary_logloss: 6.29546 + 7.41969
# [202]	cv_agg's auc: 0.832976 + 0.191438	cv_agg's l1: 0.207095 + 0.194849	cv_agg's binary_logloss: 6.2957 + 7.4195
# [203]	cv_agg's auc: 0.832964 + 0.191428	cv_agg's l1: 0.207083 + 0.194859	cv_agg's binary_logloss: 6.29602 + 7.41924
# [204]	cv_agg's auc: 0.832958 + 0.191424	cv_agg's l1: 0.207066 + 0.194872	cv_agg's binary_logloss: 6.29631 + 7.41901
# [205]	cv_agg's auc: 0.832958 + 0.191424	cv_agg's l1: 0.207057 + 0.194879	cv_agg's binary_logloss: 6.29657 + 7.4188
# [206]	cv_agg's auc: 0.83294 + 0.19141	cv_agg's l1: 0.207054 + 0.194881	cv_agg's binary_logloss: 6.29691 + 7.41852
# [207]	cv_agg's auc: 0.832946 + 0.191414	cv_agg's l1: 0.207031 + 0.194899	cv_agg's binary_logloss: 6.29713 + 7.41834
# [208]	cv_agg's auc: 0.832931 + 0.191402	cv_agg's l1: 0.207019 + 0.19491	cv_agg's binary_logloss: 6.29755 + 7.418
# [209]	cv_agg's auc: 0.832933 + 0.191404	cv_agg's l1: 0.207011 + 0.194916	cv_agg's binary_logloss: 6.29765 + 7.41792
# [210]	cv_agg's auc: 0.832929 + 0.191401	cv_agg's l1: 0.206995 + 0.194929	cv_agg's binary_logloss: 6.29784 + 7.41776
# [211]	cv_agg's auc: 0.832926 + 0.191398	cv_agg's l1: 0.206983 + 0.194939	cv_agg's binary_logloss: 6.29802 + 7.41762
# [212]	cv_agg's auc: 0.832928 + 0.1914	cv_agg's l1: 0.206967 + 0.194952	cv_agg's binary_logloss: 6.2982 + 7.41748
# [213]	cv_agg's auc: 0.832927 + 0.191399	cv_agg's l1: 0.206946 + 0.194968	cv_agg's binary_logloss: 6.29833 + 7.41737
# [214]	cv_agg's auc: 0.832924 + 0.191397	cv_agg's l1: 0.206947 + 0.194968	cv_agg's binary_logloss: 6.2986 + 7.41715
# [215]	cv_agg's auc: 0.832928 + 0.1914	cv_agg's l1: 0.206923 + 0.194988	cv_agg's binary_logloss: 6.29874 + 7.41703
# [216]	cv_agg's auc: 0.832927 + 0.191399	cv_agg's l1: 0.206908 + 0.195	cv_agg's binary_logloss: 6.29895 + 7.41686
# [217]	cv_agg's auc: 0.83293 + 0.191401	cv_agg's l1: 0.206901 + 0.195006	cv_agg's binary_logloss: 6.29909 + 7.41675
# [218]	cv_agg's auc: 0.832938 + 0.191408	cv_agg's l1: 0.206902 + 0.195005	cv_agg's binary_logloss: 6.2992 + 7.41666
# [219]	cv_agg's auc: 0.832939 + 0.191409	cv_agg's l1: 0.206897 + 0.195009	cv_agg's binary_logloss: 6.29933 + 7.41656
# [220]	cv_agg's auc: 0.832933 + 0.191403	cv_agg's l1: 0.206898 + 0.195008	cv_agg's binary_logloss: 6.29951 + 7.41641
# [221]	cv_agg's auc: 0.832942 + 0.191411	cv_agg's l1: 0.206893 + 0.195012	cv_agg's binary_logloss: 6.29958 + 7.41635
# [222]	cv_agg's auc: 0.832958 + 0.191424	cv_agg's l1: 0.206896 + 0.19501	cv_agg's binary_logloss: 6.29957 + 7.41636
# [223]	cv_agg's auc: 0.832965 + 0.191429	cv_agg's l1: 0.206885 + 0.195019	cv_agg's binary_logloss: 6.2997 + 7.41626
# [224]	cv_agg's auc: 0.832965 + 0.191429	cv_agg's l1: 0.206887 + 0.195018	cv_agg's binary_logloss: 6.29986 + 7.41613
# [225]	cv_agg's auc: 0.832908 + 0.191384	cv_agg's l1: 0.2068 + 0.195089	cv_agg's binary_logloss: 6.30095 + 7.41524
# [226]	cv_agg's auc: 0.832046 + 0.19071	cv_agg's l1: 0.207119 + 0.194829	cv_agg's binary_logloss: 6.31745 + 7.40193
# [227]	cv_agg's auc: 0.814973 + 0.180266	cv_agg's l1: 0.215081 + 0.188919	cv_agg's binary_logloss: 6.61707 + 7.18214
# [228]	cv_agg's auc: 0.804465 + 0.176826	cv_agg's l1: 0.222551 + 0.184458	cv_agg's binary_logloss: 6.95681 + 6.98688
# [229]	cv_agg's auc: 0.783207 + 0.177445	cv_agg's l1: 0.241982 + 0.178291	cv_agg's binary_logloss: 7.72623 + 6.77972
# [230]	cv_agg's auc: 0.781883 + 0.177825	cv_agg's l1: 0.261565 + 0.180512	cv_agg's binary_logloss: 8.45558 + 6.90146
# [231]	cv_agg's auc: 0.75627 + 0.192258	cv_agg's l1: 0.292576 + 0.200335	cv_agg's binary_logloss: 9.53376 + 7.60841
# [232]	cv_agg's auc: 0.756266 + 0.192253	cv_agg's l1: 0.292572 + 0.200341	cv_agg's binary_logloss: 9.53388 + 7.60826
# [233]	cv_agg's auc: 0.756261 + 0.192247	cv_agg's l1: 0.292563 + 0.200352	cv_agg's binary_logloss: 9.53391 + 7.60822
# [234]	cv_agg's auc: 0.756269 + 0.192257	cv_agg's l1: 0.292554 + 0.200362	cv_agg's binary_logloss: 9.53396 + 7.60817
# [235]	cv_agg's auc: 0.756271 + 0.192259	cv_agg's l1: 0.292558 + 0.200358	cv_agg's binary_logloss: 9.53406 + 7.60804
# [236]	cv_agg's auc: 0.756264 + 0.192251	cv_agg's l1: 0.292546 + 0.200372	cv_agg's binary_logloss: 9.53413 + 7.60796
# [237]	cv_agg's auc: 0.756274 + 0.192262	cv_agg's l1: 0.292537 + 0.200384	cv_agg's binary_logloss: 9.5342 + 7.60788
# [238]	cv_agg's auc: 0.756278 + 0.192267	cv_agg's l1: 0.292535 + 0.200387	cv_agg's binary_logloss: 9.53429 + 7.60776
# [239]	cv_agg's auc: 0.756284 + 0.192275	cv_agg's l1: 0.29252 + 0.200404	cv_agg's binary_logloss: 9.53434 + 7.60771
# [240]	cv_agg's auc: 0.756272 + 0.19226	cv_agg's l1: 0.292512 + 0.200414	cv_agg's binary_logloss: 9.53446 + 7.60756
# [241]	cv_agg's auc: 0.756284 + 0.192275	cv_agg's l1: 0.292501 + 0.200427	cv_agg's binary_logloss: 9.53452 + 7.60749
# [242]	cv_agg's auc: 0.756279 + 0.192268	cv_agg's l1: 0.292505 + 0.200422	cv_agg's binary_logloss: 9.53468 + 7.60729
# [243]	cv_agg's auc: 0.756288 + 0.192279	cv_agg's l1: 0.292507 + 0.20042	cv_agg's binary_logloss: 9.53474 + 7.60722
# [244]	cv_agg's auc: 0.756302 + 0.192295	cv_agg's l1: 0.29251 + 0.200416	cv_agg's binary_logloss: 9.53484 + 7.60709
# [245]	cv_agg's auc: 0.75632 + 0.192317	cv_agg's l1: 0.292513 + 0.200413	cv_agg's binary_logloss: 9.53488 + 7.60704
# [246]	cv_agg's auc: 0.756322 + 0.19232	cv_agg's l1: 0.29251 + 0.200416	cv_agg's binary_logloss: 9.53495 + 7.60696
# [247]	cv_agg's auc: 0.756315 + 0.192311	cv_agg's l1: 0.292513 + 0.200413	cv_agg's binary_logloss: 9.53509 + 7.60679
# [248]	cv_agg's auc: 0.756316 + 0.192313	cv_agg's l1: 0.292517 + 0.200409	cv_agg's binary_logloss: 9.53524 + 7.60661
# [249]	cv_agg's auc: 0.756306 + 0.1923	cv_agg's l1: 0.292509 + 0.200417	cv_agg's binary_logloss: 9.53533 + 7.6065
# [250]	cv_agg's auc: 0.756299 + 0.192292	cv_agg's l1: 0.292507 + 0.200421	cv_agg's binary_logloss: 9.53543 + 7.60638
# [251]	cv_agg's auc: 0.756289 + 0.19228	cv_agg's l1: 0.292493 + 0.200438	cv_agg's binary_logloss: 9.53554 + 7.60625
# [252]	cv_agg's auc: 0.756286 + 0.192277	cv_agg's l1: 0.292492 + 0.200439	cv_agg's binary_logloss: 9.53562 + 7.60615
# [253]	cv_agg's auc: 0.756279 + 0.192269	cv_agg's l1: 0.292484 + 0.200449	cv_agg's binary_logloss: 9.5357 + 7.60605
# [254]	cv_agg's auc: 0.756266 + 0.192253	cv_agg's l1: 0.292483 + 0.20045	cv_agg's binary_logloss: 9.53584 + 7.60589
# [255]	cv_agg's auc: 0.756259 + 0.192245	cv_agg's l1: 0.292481 + 0.200453	cv_agg's binary_logloss: 9.53595 + 7.60575
# [256]	cv_agg's auc: 0.756251 + 0.192235	cv_agg's l1: 0.29248 + 0.200454	cv_agg's binary_logloss: 9.53599 + 7.6057
# [257]	cv_agg's auc: 0.756256 + 0.192241	cv_agg's l1: 0.292484 + 0.200449	cv_agg's binary_logloss: 9.53604 + 7.60564
# [258]	cv_agg's auc: 0.756252 + 0.192237	cv_agg's l1: 0.292482 + 0.200451	cv_agg's binary_logloss: 9.53617 + 7.60549
# [259]	cv_agg's auc: 0.756253 + 0.192237	cv_agg's l1: 0.29248 + 0.200454	cv_agg's binary_logloss: 9.53621 + 7.60543
# [260]	cv_agg's auc: 0.756255 + 0.19224	cv_agg's l1: 0.292481 + 0.200452	cv_agg's binary_logloss: 9.53631 + 7.60531
# [261]	cv_agg's auc: 0.756256 + 0.192241	cv_agg's l1: 0.292476 + 0.200458	cv_agg's binary_logloss: 9.53639 + 7.60521
# [262]	cv_agg's auc: 0.756262 + 0.192248	cv_agg's l1: 0.292469 + 0.200466	cv_agg's binary_logloss: 9.53645 + 7.60514
# [263]	cv_agg's auc: 0.756269 + 0.192257	cv_agg's l1: 0.292463 + 0.200474	cv_agg's binary_logloss: 9.53648 + 7.60511
# [264]	cv_agg's auc: 0.756266 + 0.192253	cv_agg's l1: 0.292459 + 0.200479	cv_agg's binary_logloss: 9.53656 + 7.605
# [265]	cv_agg's auc: 0.756254 + 0.192239	cv_agg's l1: 0.292462 + 0.200476	cv_agg's binary_logloss: 9.5366 + 7.60496
# [266]	cv_agg's auc: 0.756251 + 0.192236	cv_agg's l1: 0.292463 + 0.200474	cv_agg's binary_logloss: 9.53664 + 7.60491
# [267]	cv_agg's auc: 0.756238 + 0.19222	cv_agg's l1: 0.292457 + 0.200481	cv_agg's binary_logloss: 9.53669 + 7.60485
# [268]	cv_agg's auc: 0.756236 + 0.192217	cv_agg's l1: 0.292452 + 0.200487	cv_agg's binary_logloss: 9.53673 + 7.6048
# [269]	cv_agg's auc: 0.756231 + 0.192211	cv_agg's l1: 0.292452 + 0.200487	cv_agg's binary_logloss: 9.5368 + 7.60472
# [270]	cv_agg's auc: 0.756236 + 0.192218	cv_agg's l1: 0.292452 + 0.200487	cv_agg's binary_logloss: 9.53689 + 7.60461
# [271]	cv_agg's auc: 0.756242 + 0.192225	cv_agg's l1: 0.292443 + 0.200498	cv_agg's binary_logloss: 9.53697 + 7.60451
# [272]	cv_agg's auc: 0.756237 + 0.192219	cv_agg's l1: 0.292441 + 0.2005	cv_agg's binary_logloss: 9.53704 + 7.60442
# [273]	cv_agg's auc: 0.756242 + 0.192224	cv_agg's l1: 0.29243 + 0.200514	cv_agg's binary_logloss: 9.53707 + 7.60439
# [274]	cv_agg's auc: 0.756243 + 0.192225	cv_agg's l1: 0.292423 + 0.200522	cv_agg's binary_logloss: 9.53717 + 7.60426
# [275]	cv_agg's auc: 0.756246 + 0.192229	cv_agg's l1: 0.292422 + 0.200524	cv_agg's binary_logloss: 9.53725 + 7.60417
# [276]	cv_agg's auc: 0.756248 + 0.192232	cv_agg's l1: 0.292416 + 0.200532	cv_agg's binary_logloss: 9.53729 + 7.60412
# [277]	cv_agg's auc: 0.756259 + 0.192244	cv_agg's l1: 0.292408 + 0.200541	cv_agg's binary_logloss: 9.5373 + 7.6041
# [278]	cv_agg's auc: 0.756258 + 0.192244	cv_agg's l1: 0.292406 + 0.200544	cv_agg's binary_logloss: 9.53736 + 7.60404
# [279]	cv_agg's auc: 0.756261 + 0.192247	cv_agg's l1: 0.292406 + 0.200544	cv_agg's binary_logloss: 9.53747 + 7.6039
# [280]	cv_agg's auc: 0.756259 + 0.192245	cv_agg's l1: 0.292398 + 0.200554	cv_agg's binary_logloss: 9.53752 + 7.60384
# [281]	cv_agg's auc: 0.756251 + 0.192236	cv_agg's l1: 0.2924 + 0.200551	cv_agg's binary_logloss: 9.53765 + 7.60368
# [282]	cv_agg's auc: 0.756242 + 0.192225	cv_agg's l1: 0.2924 + 0.200551	cv_agg's binary_logloss: 9.53775 + 7.60355
# [283]	cv_agg's auc: 0.75625 + 0.192234	cv_agg's l1: 0.292395 + 0.200556	cv_agg's binary_logloss: 9.53777 + 7.60353
# [284]	cv_agg's auc: 0.756256 + 0.192241	cv_agg's l1: 0.292395 + 0.200557	cv_agg's binary_logloss: 9.53784 + 7.60345
# [285]	cv_agg's auc: 0.756256 + 0.19224	cv_agg's l1: 0.292395 + 0.200557	cv_agg's binary_logloss: 9.53786 + 7.60343
# [286]	cv_agg's auc: 0.756255 + 0.19224	cv_agg's l1: 0.292386 + 0.200567	cv_agg's binary_logloss: 9.53798 + 7.60328
# [287]	cv_agg's auc: 0.756261 + 0.192247	cv_agg's l1: 0.292389 + 0.200565	cv_agg's binary_logloss: 9.53803 + 7.60322
# [288]	cv_agg's auc: 0.756255 + 0.19224	cv_agg's l1: 0.292393 + 0.200559	cv_agg's binary_logloss: 9.5381 + 7.60314
# [289]	cv_agg's auc: 0.756261 + 0.192247	cv_agg's l1: 0.292389 + 0.200565	cv_agg's binary_logloss: 9.53816 + 7.60306
# [290]	cv_agg's auc: 0.756259 + 0.192245	cv_agg's l1: 0.292393 + 0.200559	cv_agg's binary_logloss: 9.53824 + 7.60297
# [291]	cv_agg's auc: 0.756258 + 0.192244	cv_agg's l1: 0.292392 + 0.200561	cv_agg's binary_logloss: 9.53829 + 7.6029
# [292]	cv_agg's auc: 0.756258 + 0.192243	cv_agg's l1: 0.292398 + 0.200553	cv_agg's binary_logloss: 9.53839 + 7.60278
# [293]	cv_agg's auc: 0.756262 + 0.192248	cv_agg's l1: 0.292389 + 0.200564	cv_agg's binary_logloss: 9.53842 + 7.60274
# [294]	cv_agg's auc: 0.756256 + 0.192241	cv_agg's l1: 0.292379 + 0.200576	cv_agg's binary_logloss: 9.53848 + 7.60267
# [295]	cv_agg's auc: 0.756257 + 0.192242	cv_agg's l1: 0.292377 + 0.200579	cv_agg's binary_logloss: 9.53851 + 7.60264
# [296]	cv_agg's auc: 0.756262 + 0.192248	cv_agg's l1: 0.292376 + 0.200579	cv_agg's binary_logloss: 9.53855 + 7.60259
# [297]	cv_agg's auc: 0.756268 + 0.192255	cv_agg's l1: 0.29238 + 0.200575	cv_agg's binary_logloss: 9.53862 + 7.6025
# [298]	cv_agg's auc: 0.756265 + 0.192251	cv_agg's l1: 0.292388 + 0.200565	cv_agg's binary_logloss: 9.53873 + 7.60237
# [299]	cv_agg's auc: 0.756263 + 0.192249	cv_agg's l1: 0.292387 + 0.200566	cv_agg's binary_logloss: 9.53882 + 7.60226
# [300]	cv_agg's auc: 0.756268 + 0.192255	cv_agg's l1: 0.292391 + 0.200562	cv_agg's binary_logloss: 9.53886 + 7.60221
# [301]	cv_agg's auc: 0.756272 + 0.19226	cv_agg's l1: 0.292385 + 0.200569	cv_agg's binary_logloss: 9.53889 + 7.60217
# [302]	cv_agg's auc: 0.756277 + 0.192266	cv_agg's l1: 0.292384 + 0.200571	cv_agg's binary_logloss: 9.53897 + 7.60208
# [303]	cv_agg's auc: 0.756275 + 0.192264	cv_agg's l1: 0.292383 + 0.200572	cv_agg's binary_logloss: 9.53903 + 7.60201
# [304]	cv_agg's auc: 0.756271 + 0.192259	cv_agg's l1: 0.292386 + 0.200568	cv_agg's binary_logloss: 9.53908 + 7.60194
# [305]	cv_agg's auc: 0.756268 + 0.192255	cv_agg's l1: 0.29238 + 0.200576	cv_agg's binary_logloss: 9.53912 + 7.6019
# [306]	cv_agg's auc: 0.756262 + 0.192248	cv_agg's l1: 0.292371 + 0.200587	cv_agg's binary_logloss: 9.53917 + 7.60183
# [307]	cv_agg's auc: 0.756258 + 0.192243	cv_agg's l1: 0.292366 + 0.200592	cv_agg's binary_logloss: 9.53922 + 7.60177
# [308]	cv_agg's auc: 0.756257 + 0.192243	cv_agg's l1: 0.292358 + 0.200602	cv_agg's binary_logloss: 9.53924 + 7.60174
# [309]	cv_agg's auc: 0.756248 + 0.192232	cv_agg's l1: 0.292358 + 0.200601	cv_agg's binary_logloss: 9.53933 + 7.60164
# [310]	cv_agg's auc: 0.756247 + 0.19223	cv_agg's l1: 0.292357 + 0.200602	cv_agg's binary_logloss: 9.5394 + 7.60155
# [311]	cv_agg's auc: 0.75625 + 0.192233	cv_agg's l1: 0.29236 + 0.200599	cv_agg's binary_logloss: 9.5395 + 7.60143
# [312]	cv_agg's auc: 0.756251 + 0.192235	cv_agg's l1: 0.292354 + 0.200606	cv_agg's binary_logloss: 9.53952 + 7.60141
# [313]	cv_agg's auc: 0.756255 + 0.19224	cv_agg's l1: 0.292355 + 0.200606	cv_agg's binary_logloss: 9.53963 + 7.60127
# [314]	cv_agg's auc: 0.756259 + 0.192245	cv_agg's l1: 0.292352 + 0.200609	cv_agg's binary_logloss: 9.53969 + 7.6012
# [315]	cv_agg's auc: 0.756265 + 0.192251	cv_agg's l1: 0.292342 + 0.200621	cv_agg's binary_logloss: 9.53969 + 7.60121
# [316]	cv_agg's auc: 0.756264 + 0.192251	cv_agg's l1: 0.292342 + 0.200621	cv_agg's binary_logloss: 9.53977 + 7.6011
# [317]	cv_agg's auc: 0.756259 + 0.192245	cv_agg's l1: 0.292343 + 0.200619	cv_agg's binary_logloss: 9.53984 + 7.60102
# [318]	cv_agg's auc: 0.75626 + 0.192246	cv_agg's l1: 0.29234 + 0.200623	cv_agg's binary_logloss: 9.5399 + 7.60095
# [319]	cv_agg's auc: 0.756258 + 0.192244	cv_agg's l1: 0.292334 + 0.200631	cv_agg's binary_logloss: 9.53993 + 7.60091
# [320]	cv_agg's auc: 0.756263 + 0.19225	cv_agg's l1: 0.292334 + 0.200631	cv_agg's binary_logloss: 9.53994 + 7.6009
# [321]	cv_agg's auc: 0.756257 + 0.192242	cv_agg's l1: 0.292323 + 0.200644	cv_agg's binary_logloss: 9.53996 + 7.60087
# [322]	cv_agg's auc: 0.756247 + 0.192231	cv_agg's l1: 0.292317 + 0.200652	cv_agg's binary_logloss: 9.54007 + 7.60074
# [323]	cv_agg's auc: 0.756248 + 0.192231	cv_agg's l1: 0.292311 + 0.200658	cv_agg's binary_logloss: 9.54012 + 7.60068
# [324]	cv_agg's auc: 0.756245 + 0.192228	cv_agg's l1: 0.292312 + 0.200658	cv_agg's binary_logloss: 9.54018 + 7.60061
# [325]	cv_agg's auc: 0.75624 + 0.192223	cv_agg's l1: 0.292311 + 0.200659	cv_agg's binary_logloss: 9.54024 + 7.60053
# [326]	cv_agg's auc: 0.75624 + 0.192222	cv_agg's l1: 0.292309 + 0.200661	cv_agg's binary_logloss: 9.5403 + 7.60046
# [327]	cv_agg's auc: 0.756237 + 0.192219	cv_agg's l1: 0.292304 + 0.200667	cv_agg's binary_logloss: 9.54031 + 7.60044
# [328]	cv_agg's auc: 0.756235 + 0.192216	cv_agg's l1: 0.292304 + 0.200667	cv_agg's binary_logloss: 9.54038 + 7.60037
# [329]	cv_agg's auc: 0.756233 + 0.192213	cv_agg's l1: 0.2923 + 0.200671	cv_agg's binary_logloss: 9.54046 + 7.60026
# [330]	cv_agg's auc: 0.756238 + 0.19222	cv_agg's l1: 0.292301 + 0.200671	cv_agg's binary_logloss: 9.54051 + 7.60021
# [331]	cv_agg's auc: 0.756241 + 0.192223	cv_agg's l1: 0.292298 + 0.200674	cv_agg's binary_logloss: 9.54052 + 7.6002
# [332]	cv_agg's auc: 0.756241 + 0.192223	cv_agg's l1: 0.292288 + 0.200686	cv_agg's binary_logloss: 9.54052 + 7.6002
# [333]	cv_agg's auc: 0.756241 + 0.192223	cv_agg's l1: 0.292283 + 0.200693	cv_agg's binary_logloss: 9.54054 + 7.60017
# [334]	cv_agg's auc: 0.756237 + 0.192218	cv_agg's l1: 0.292278 + 0.200699	cv_agg's binary_logloss: 9.5406 + 7.6001
# [335]	cv_agg's auc: 0.756242 + 0.192224	cv_agg's l1: 0.29227 + 0.200709	cv_agg's binary_logloss: 9.54061 + 7.60009
# [336]	cv_agg's auc: 0.756238 + 0.192219	cv_agg's l1: 0.292268 + 0.200711	cv_agg's binary_logloss: 9.54073 + 7.59994
# [337]	cv_agg's auc: 0.756235 + 0.192216	cv_agg's l1: 0.292266 + 0.200713	cv_agg's binary_logloss: 9.54077 + 7.59989
# [338]	cv_agg's auc: 0.756233 + 0.192214	cv_agg's l1: 0.292263 + 0.200717	cv_agg's binary_logloss: 9.54083 + 7.59981
# [339]	cv_agg's auc: 0.756231 + 0.192211	cv_agg's l1: 0.292264 + 0.200715	cv_agg's binary_logloss: 9.5409 + 7.59973
# [340]	cv_agg's auc: 0.75623 + 0.19221	cv_agg's l1: 0.292262 + 0.200718	cv_agg's binary_logloss: 9.54098 + 7.59964
# [341]	cv_agg's auc: 0.756228 + 0.192208	cv_agg's l1: 0.292265 + 0.200714	cv_agg's binary_logloss: 9.54104 + 7.59956
# [342]	cv_agg's auc: 0.756227 + 0.192207	cv_agg's l1: 0.292256 + 0.200725	cv_agg's binary_logloss: 9.54104 + 7.59957
# [343]	cv_agg's auc: 0.756229 + 0.192209	cv_agg's l1: 0.292253 + 0.200729	cv_agg's binary_logloss: 9.54108 + 7.59951
# [344]	cv_agg's auc: 0.756229 + 0.192209	cv_agg's l1: 0.292249 + 0.200734	cv_agg's binary_logloss: 9.54112 + 7.59946
# [345]	cv_agg's auc: 0.756233 + 0.192213	cv_agg's l1: 0.292246 + 0.200737	cv_agg's binary_logloss: 9.54111 + 7.59948
# [346]	cv_agg's auc: 0.756227 + 0.192206	cv_agg's l1: 0.292246 + 0.200737	cv_agg's binary_logloss: 9.5412 + 7.59937
# [347]	cv_agg's auc: 0.756228 + 0.192208	cv_agg's l1: 0.292248 + 0.200734	cv_agg's binary_logloss: 9.54125 + 7.5993
# [348]	cv_agg's auc: 0.756227 + 0.192206	cv_agg's l1: 0.292247 + 0.200736	cv_agg's binary_logloss: 9.54128 + 7.59927
# [349]	cv_agg's auc: 0.756229 + 0.192209	cv_agg's l1: 0.292249 + 0.200734	cv_agg's binary_logloss: 9.54134 + 7.5992
# [350]	cv_agg's auc: 0.756225 + 0.192204	cv_agg's l1: 0.292252 + 0.20073	cv_agg's binary_logloss: 9.5414 + 7.59913
# [351]	cv_agg's auc: 0.756223 + 0.192202	cv_agg's l1: 0.292247 + 0.200736	cv_agg's binary_logloss: 9.54142 + 7.5991
# [352]	cv_agg's auc: 0.756217 + 0.192195	cv_agg's l1: 0.292244 + 0.200739	cv_agg's binary_logloss: 9.54148 + 7.59903
# [353]	cv_agg's auc: 0.756225 + 0.192204	cv_agg's l1: 0.292238 + 0.200747	cv_agg's binary_logloss: 9.5415 + 7.59901
# [354]	cv_agg's auc: 0.756224 + 0.192203	cv_agg's l1: 0.292234 + 0.200751	cv_agg's binary_logloss: 9.54157 + 7.59892
# [355]	cv_agg's auc: 0.756222 + 0.192201	cv_agg's l1: 0.29223 + 0.200757	cv_agg's binary_logloss: 9.5416 + 7.59888
# [356]	cv_agg's auc: 0.756218 + 0.192196	cv_agg's l1: 0.292229 + 0.200758	cv_agg's binary_logloss: 9.54166 + 7.59881
# [357]	cv_agg's auc: 0.756222 + 0.1922	cv_agg's l1: 0.292227 + 0.20076	cv_agg's binary_logloss: 9.54169 + 7.59878
# [358]	cv_agg's auc: 0.756215 + 0.192193	cv_agg's l1: 0.292231 + 0.200755	cv_agg's binary_logloss: 9.54176 + 7.59869
# [359]	cv_agg's auc: 0.756216 + 0.192193	cv_agg's l1: 0.292226 + 0.200762	cv_agg's binary_logloss: 9.54182 + 7.59861
# [360]	cv_agg's auc: 0.756215 + 0.192192	cv_agg's l1: 0.292224 + 0.200764	cv_agg's binary_logloss: 9.54189 + 7.59853
# [361]	cv_agg's auc: 0.754429 + 0.190098	cv_agg's l1: 0.293014 + 0.199794	cv_agg's binary_logloss: 9.56335 + 7.5725
# [362]	cv_agg's auc: 0.752637 + 0.188042	cv_agg's l1: 0.293819 + 0.198814	cv_agg's binary_logloss: 9.6071 + 7.5199
# [363]	cv_agg's auc: 0.718759 + 0.159667	cv_agg's l1: 0.311206 + 0.179867	cv_agg's binary_logloss: 10.2589 + 6.82176
# [364]	cv_agg's auc: 0.700818 + 0.154878	cv_agg's l1: 0.334834 + 0.162728	cv_agg's binary_logloss: 11.1648 + 6.18601
# [365]	cv_agg's auc: 0.709555 + 0.156206	cv_agg's l1: 0.361513 + 0.158797	cv_agg's binary_logloss: 12.1762 + 6.06544
# [366]	cv_agg's auc: 0.688666 + 0.156303	cv_agg's l1: 0.381064 + 0.16705	cv_agg's binary_logloss: 12.8601 + 6.35818
# [367]	cv_agg's auc: 0.688699 + 0.156283	cv_agg's l1: 0.382934 + 0.168303	cv_agg's binary_logloss: 12.9248 + 6.40028
# [368]	cv_agg's auc: 0.6887 + 0.156284	cv_agg's l1: 0.382935 + 0.168302	cv_agg's binary_logloss: 12.9248 + 6.40022
# [369]	cv_agg's auc: 0.688701 + 0.156287	cv_agg's l1: 0.382934 + 0.168302	cv_agg's binary_logloss: 12.9248 + 6.40021
# [370]	cv_agg's auc: 0.688701 + 0.156286	cv_agg's l1: 0.382931 + 0.168308	cv_agg's binary_logloss: 12.9248 + 6.40021
# [371]	cv_agg's auc: 0.688701 + 0.156286	cv_agg's l1: 0.38293 + 0.16831	cv_agg's binary_logloss: 12.9248 + 6.40019
# [372]	cv_agg's auc: 0.688701 + 0.156286	cv_agg's l1: 0.382931 + 0.168309	cv_agg's binary_logloss: 12.9249 + 6.40012
# [373]	cv_agg's auc: 0.6887 + 0.156285	cv_agg's l1: 0.382927 + 0.168316	cv_agg's binary_logloss: 12.9249 + 6.40011
# [374]	cv_agg's auc: 0.688704 + 0.156292	cv_agg's l1: 0.382923 + 0.168325	cv_agg's binary_logloss: 12.9248 + 6.40015
# [375]	cv_agg's auc: 0.688702 + 0.156288	cv_agg's l1: 0.382917 + 0.168336	cv_agg's binary_logloss: 12.9249 + 6.40015
# [376]	cv_agg's auc: 0.688699 + 0.156283	cv_agg's l1: 0.382911 + 0.168348	cv_agg's binary_logloss: 12.9248 + 6.40018
# [377]	cv_agg's auc: 0.688701 + 0.156287	cv_agg's l1: 0.382915 + 0.16834	cv_agg's binary_logloss: 12.9249 + 6.4001
# [378]	cv_agg's auc: 0.688705 + 0.156293	cv_agg's l1: 0.382913 + 0.168344	cv_agg's binary_logloss: 12.9249 + 6.40011
# [379]	cv_agg's auc: 0.688705 + 0.156295	cv_agg's l1: 0.382918 + 0.168334	cv_agg's binary_logloss: 12.9249 + 6.40001
# [380]	cv_agg's auc: 0.68871 + 0.156303	cv_agg's l1: 0.382913 + 0.168344	cv_agg's binary_logloss: 12.9249 + 6.40007
# [381]	cv_agg's auc: 0.688709 + 0.156301	cv_agg's l1: 0.382917 + 0.168336	cv_agg's binary_logloss: 12.9249 + 6.39999
# [382]	cv_agg's auc: 0.688707 + 0.156298	cv_agg's l1: 0.382919 + 0.168333	cv_agg's binary_logloss: 12.9249 + 6.39996
# [383]	cv_agg's auc: 0.688708 + 0.1563	cv_agg's l1: 0.382919 + 0.168332	cv_agg's binary_logloss: 12.925 + 6.39994
# [384]	cv_agg's auc: 0.688713 + 0.156309	cv_agg's l1: 0.382915 + 0.16834	cv_agg's binary_logloss: 12.925 + 6.39992
# [385]	cv_agg's auc: 0.688716 + 0.156314	cv_agg's l1: 0.38291 + 0.16835	cv_agg's binary_logloss: 12.925 + 6.39992
# [386]	cv_agg's auc: 0.688713 + 0.156308	cv_agg's l1: 0.382911 + 0.168348	cv_agg's binary_logloss: 12.925 + 6.39985
# [387]	cv_agg's auc: 0.688708 + 0.156299	cv_agg's l1: 0.382908 + 0.168354	cv_agg's binary_logloss: 12.925 + 6.39981
# [388]	cv_agg's auc: 0.688709 + 0.156301	cv_agg's l1: 0.382909 + 0.168351	cv_agg's binary_logloss: 12.925 + 6.39977
# [389]	cv_agg's auc: 0.688707 + 0.156298	cv_agg's l1: 0.382905 + 0.16836	cv_agg's binary_logloss: 12.9251 + 6.39973
# [390]	cv_agg's auc: 0.688708 + 0.1563	cv_agg's l1: 0.382902 + 0.168365	cv_agg's binary_logloss: 12.9251 + 6.39968
# [391]	cv_agg's auc: 0.68871 + 0.156303	cv_agg's l1: 0.382907 + 0.168356	cv_agg's binary_logloss: 12.9251 + 6.39968
# [392]	cv_agg's auc: 0.688709 + 0.156302	cv_agg's l1: 0.382908 + 0.168354	cv_agg's binary_logloss: 12.9251 + 6.39964
# [393]	cv_agg's auc: 0.688709 + 0.156301	cv_agg's l1: 0.382904 + 0.168361	cv_agg's binary_logloss: 12.9251 + 6.39965
# [394]	cv_agg's auc: 0.688707 + 0.156297	cv_agg's l1: 0.382904 + 0.168361	cv_agg's binary_logloss: 12.9251 + 6.39957
# [395]	cv_agg's auc: 0.688709 + 0.156302	cv_agg's l1: 0.382903 + 0.168363	cv_agg's binary_logloss: 12.9251 + 6.39961
# [396]	cv_agg's auc: 0.688708 + 0.156299	cv_agg's l1: 0.382907 + 0.168355	cv_agg's binary_logloss: 12.9251 + 6.39957
# [397]	cv_agg's auc: 0.688707 + 0.156298	cv_agg's l1: 0.382906 + 0.168358	cv_agg's binary_logloss: 12.9251 + 6.39958
# [398]	cv_agg's auc: 0.688709 + 0.156301	cv_agg's l1: 0.382904 + 0.168361	cv_agg's binary_logloss: 12.9251 + 6.39957
# [399]	cv_agg's auc: 0.688707 + 0.156297	cv_agg's l1: 0.382904 + 0.168361	cv_agg's binary_logloss: 12.9252 + 6.39948
# [400]	cv_agg's auc: 0.688707 + 0.156297	cv_agg's l1: 0.382905 + 0.16836	cv_agg's binary_logloss: 12.9252 + 6.39943
# [401]	cv_agg's auc: 0.688706 + 0.156297	cv_agg's l1: 0.382903 + 0.168363	cv_agg's binary_logloss: 12.9253 + 6.39936
# [402]	cv_agg's auc: 0.688704 + 0.156292	cv_agg's l1: 0.382901 + 0.168367	cv_agg's binary_logloss: 12.9253 + 6.3993
# ...
# [2867]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382717 + 0.168729	cv_agg's binary_logloss: 12.9355 + 6.37917
# [2868]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382717 + 0.168729	cv_agg's binary_logloss: 12.9355 + 6.37914
# [2869]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382718 + 0.168728	cv_agg's binary_logloss: 12.9355 + 6.37914
# [2870]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382718 + 0.168726	cv_agg's binary_logloss: 12.9355 + 6.37912
# [2871]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382719 + 0.168725	cv_agg's binary_logloss: 12.9355 + 6.37909
# [2872]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382719 + 0.168724	cv_agg's binary_logloss: 12.9356 + 6.37907
# [2873]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382718 + 0.168726	cv_agg's binary_logloss: 12.9355 + 6.37909
# [2874]	cv_agg's auc: 0.688516 + 0.155935	cv_agg's l1: 0.382718 + 0.168727	cv_agg's binary_logloss: 12.9355 + 6.37911
# [2875]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382717 + 0.168728	cv_agg's binary_logloss: 12.9355 + 6.37912
# [2876]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382717 + 0.168728	cv_agg's binary_logloss: 12.9355 + 6.37911
# [2877]	cv_agg's auc: 0.688515 + 0.155933	cv_agg's l1: 0.382717 + 0.168729	cv_agg's binary_logloss: 12.9355 + 6.37912
# [2878]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382717 + 0.16873	cv_agg's binary_logloss: 12.9355 + 6.37913
# [2879]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382716 + 0.168731	cv_agg's binary_logloss: 12.9355 + 6.37915
# [2880]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382715 + 0.168732	cv_agg's binary_logloss: 12.9355 + 6.37916
# [2881]	cv_agg's auc: 0.688514 + 0.155933	cv_agg's l1: 0.382715 + 0.168732	cv_agg's binary_logloss: 12.9355 + 6.37913
# [2882]	cv_agg's auc: 0.688514 + 0.155933	cv_agg's l1: 0.382715 + 0.168733	cv_agg's binary_logloss: 12.9355 + 6.37912
# [2883]	cv_agg's auc: 0.688514 + 0.155932	cv_agg's l1: 0.382715 + 0.168733	cv_agg's binary_logloss: 12.9355 + 6.3791
# [2884]	cv_agg's auc: 0.688515 + 0.155933	cv_agg's l1: 0.382714 + 0.168735	cv_agg's binary_logloss: 12.9355 + 6.37911
# [2885]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382713 + 0.168736	cv_agg's binary_logloss: 12.9355 + 6.37911
# [2886]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382713 + 0.168737	cv_agg's binary_logloss: 12.9355 + 6.37912
# [2887]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382712 + 0.168738	cv_agg's binary_logloss: 12.9355 + 6.37913
# [2888]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382713 + 0.168737	cv_agg's binary_logloss: 12.9355 + 6.37915
# [2889]	cv_agg's auc: 0.688517 + 0.155938	cv_agg's l1: 0.382711 + 0.16874	cv_agg's binary_logloss: 12.9355 + 6.37918
# [2890]	cv_agg's auc: 0.688519 + 0.155941	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9355 + 6.37923
# [2891]	cv_agg's auc: 0.688519 + 0.155943	cv_agg's l1: 0.38271 + 0.168743	cv_agg's binary_logloss: 12.9355 + 6.37925
# [2892]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37928
# [2893]	cv_agg's auc: 0.688518 + 0.15594	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2894]	cv_agg's auc: 0.688518 + 0.155939	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37928
# [2895]	cv_agg's auc: 0.688518 + 0.155939	cv_agg's l1: 0.382708 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2896]	cv_agg's auc: 0.688518 + 0.155941	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37931
# [2897]	cv_agg's auc: 0.688519 + 0.155941	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9354 + 6.37931
# [2898]	cv_agg's auc: 0.688519 + 0.155942	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37932
# [2899]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37934
# [2900]	cv_agg's auc: 0.688521 + 0.155945	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37935
# [2901]	cv_agg's auc: 0.688522 + 0.155947	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9354 + 6.37935
# [2902]	cv_agg's auc: 0.688521 + 0.155946	cv_agg's l1: 0.382707 + 0.168748	cv_agg's binary_logloss: 12.9354 + 6.37936
# [2903]	cv_agg's auc: 0.68852 + 0.155944	cv_agg's l1: 0.382707 + 0.168749	cv_agg's binary_logloss: 12.9354 + 6.37936
# [2904]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382706 + 0.16875	cv_agg's binary_logloss: 12.9354 + 6.37937
# [2905]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382707 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37937
# [2906]	cv_agg's auc: 0.68852 + 0.155944	cv_agg's l1: 0.382707 + 0.168748	cv_agg's binary_logloss: 12.9354 + 6.37937
# [2907]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9354 + 6.37937
# [2908]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37936
# [2909]	cv_agg's auc: 0.688521 + 0.155945	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9354 + 6.37937
# [2910]	cv_agg's auc: 0.688521 + 0.155945	cv_agg's l1: 0.38271 + 0.168742	cv_agg's binary_logloss: 12.9354 + 6.37939
# [2911]	cv_agg's auc: 0.688521 + 0.155946	cv_agg's l1: 0.38271 + 0.168743	cv_agg's binary_logloss: 12.9354 + 6.37939
# [2912]	cv_agg's auc: 0.688522 + 0.155947	cv_agg's l1: 0.38271 + 0.168743	cv_agg's binary_logloss: 12.9354 + 6.37938
# [2913]	cv_agg's auc: 0.688521 + 0.155946	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9354 + 6.37936
# [2914]	cv_agg's auc: 0.688521 + 0.155945	cv_agg's l1: 0.38271 + 0.168742	cv_agg's binary_logloss: 12.9354 + 6.37937
# [2915]	cv_agg's auc: 0.688522 + 0.155947	cv_agg's l1: 0.38271 + 0.168743	cv_agg's binary_logloss: 12.9354 + 6.37938
# [2916]	cv_agg's auc: 0.688522 + 0.155948	cv_agg's l1: 0.38271 + 0.168742	cv_agg's binary_logloss: 12.9354 + 6.37937
# [2917]	cv_agg's auc: 0.688523 + 0.155949	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9354 + 6.37936
# [2918]	cv_agg's auc: 0.688523 + 0.155949	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37934
# [2919]	cv_agg's auc: 0.688522 + 0.155948	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37933
# [2920]	cv_agg's auc: 0.688522 + 0.155947	cv_agg's l1: 0.38271 + 0.168743	cv_agg's binary_logloss: 12.9354 + 6.37931
# [2921]	cv_agg's auc: 0.68852 + 0.155944	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9354 + 6.37931
# [2922]	cv_agg's auc: 0.688521 + 0.155945	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37931
# [2923]	cv_agg's auc: 0.688521 + 0.155945	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.3793
# [2924]	cv_agg's auc: 0.688521 + 0.155946	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2925]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382707 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2926]	cv_agg's auc: 0.688521 + 0.155945	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9354 + 6.37928
# [2927]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2928]	cv_agg's auc: 0.688519 + 0.155941	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2929]	cv_agg's auc: 0.688519 + 0.155942	cv_agg's l1: 0.382709 + 0.168744	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2930]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2931]	cv_agg's auc: 0.688518 + 0.15594	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2932]	cv_agg's auc: 0.688518 + 0.155941	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37928
# [2933]	cv_agg's auc: 0.68852 + 0.155943	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2934]	cv_agg's auc: 0.688518 + 0.155941	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2935]	cv_agg's auc: 0.688519 + 0.155941	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2936]	cv_agg's auc: 0.688519 + 0.155941	cv_agg's l1: 0.382708 + 0.168745	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2937]	cv_agg's auc: 0.688518 + 0.155941	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2938]	cv_agg's auc: 0.688518 + 0.155939	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9355 + 6.37926
# [2939]	cv_agg's auc: 0.688517 + 0.155938	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9355 + 6.37926
# [2940]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382707 + 0.168748	cv_agg's binary_logloss: 12.9355 + 6.37924
# [2941]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382707 + 0.168748	cv_agg's binary_logloss: 12.9355 + 6.37924
# [2942]	cv_agg's auc: 0.688516 + 0.155937	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9355 + 6.37922
# [2943]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9355 + 6.37922
# [2944]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9355 + 6.37922
# [2945]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382708 + 0.168746	cv_agg's binary_logloss: 12.9355 + 6.37922
# [2946]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382709 + 0.168745	cv_agg's binary_logloss: 12.9355 + 6.37921
# [2947]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382706 + 0.16875	cv_agg's binary_logloss: 12.9355 + 6.37924
# [2948]	cv_agg's auc: 0.688516 + 0.155937	cv_agg's l1: 0.382706 + 0.168751	cv_agg's binary_logloss: 12.9355 + 6.37924
# [2949]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382706 + 0.168751	cv_agg's binary_logloss: 12.9355 + 6.37925
# [2950]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9355 + 6.37925
# [2951]	cv_agg's auc: 0.688515 + 0.155935	cv_agg's l1: 0.382702 + 0.168758	cv_agg's binary_logloss: 12.9355 + 6.37926
# [2952]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382703 + 0.168757	cv_agg's binary_logloss: 12.9354 + 6.37928
# [2953]	cv_agg's auc: 0.688515 + 0.155933	cv_agg's l1: 0.382703 + 0.168757	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2954]	cv_agg's auc: 0.688514 + 0.155933	cv_agg's l1: 0.382702 + 0.168757	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2955]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382703 + 0.168756	cv_agg's binary_logloss: 12.9354 + 6.37931
# [2956]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9354 + 6.3793
# [2957]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382705 + 0.168752	cv_agg's binary_logloss: 12.9354 + 6.37932
# [2958]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9354 + 6.37932
# [2959]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382703 + 0.168755	cv_agg's binary_logloss: 12.9354 + 6.37933
# [2960]	cv_agg's auc: 0.688516 + 0.155935	cv_agg's l1: 0.382704 + 0.168755	cv_agg's binary_logloss: 12.9354 + 6.37934
# [2961]	cv_agg's auc: 0.688515 + 0.155934	cv_agg's l1: 0.382703 + 0.168756	cv_agg's binary_logloss: 12.9354 + 6.37934
# [2962]	cv_agg's auc: 0.688516 + 0.155936	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9354 + 6.37933
# [2963]	cv_agg's auc: 0.688515 + 0.155933	cv_agg's l1: 0.382705 + 0.168752	cv_agg's binary_logloss: 12.9354 + 6.37931
# [2964]	cv_agg's auc: 0.688514 + 0.155933	cv_agg's l1: 0.382705 + 0.168752	cv_agg's binary_logloss: 12.9354 + 6.3793
# [2965]	cv_agg's auc: 0.688514 + 0.155932	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2966]	cv_agg's auc: 0.688513 + 0.155931	cv_agg's l1: 0.382703 + 0.168756	cv_agg's binary_logloss: 12.9354 + 6.3793
# [2967]	cv_agg's auc: 0.688513 + 0.155931	cv_agg's l1: 0.382703 + 0.168755	cv_agg's binary_logloss: 12.9354 + 6.37929
# [2968]	cv_agg's auc: 0.688513 + 0.15593	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2969]	cv_agg's auc: 0.688513 + 0.15593	cv_agg's l1: 0.382703 + 0.168755	cv_agg's binary_logloss: 12.9354 + 6.37928
# [2970]	cv_agg's auc: 0.688512 + 0.155929	cv_agg's l1: 0.382703 + 0.168756	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2971]	cv_agg's auc: 0.688513 + 0.155931	cv_agg's l1: 0.382703 + 0.168757	cv_agg's binary_logloss: 12.9355 + 6.37926
# [2972]	cv_agg's auc: 0.688513 + 0.15593	cv_agg's l1: 0.382703 + 0.168756	cv_agg's binary_logloss: 12.9355 + 6.37927
# [2973]	cv_agg's auc: 0.688511 + 0.155927	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9355 + 6.37924
# [2974]	cv_agg's auc: 0.688511 + 0.155927	cv_agg's l1: 0.382704 + 0.168753	cv_agg's binary_logloss: 12.9355 + 6.37923
# [2975]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9355 + 6.37921
# [2976]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382704 + 0.168754	cv_agg's binary_logloss: 12.9355 + 6.37922
# [2977]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382705 + 0.168752	cv_agg's binary_logloss: 12.9355 + 6.37919
# [2978]	cv_agg's auc: 0.68851 + 0.155924	cv_agg's l1: 0.382705 + 0.168753	cv_agg's binary_logloss: 12.9355 + 6.37919
# [2979]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382705 + 0.168752	cv_agg's binary_logloss: 12.9355 + 6.37916
# [2980]	cv_agg's auc: 0.688509 + 0.155923	cv_agg's l1: 0.382706 + 0.168751	cv_agg's binary_logloss: 12.9355 + 6.37915
# [2981]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382705 + 0.168753	cv_agg's binary_logloss: 12.9355 + 6.37915
# [2982]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382705 + 0.168753	cv_agg's binary_logloss: 12.9355 + 6.37916
# [2983]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382706 + 0.168751	cv_agg's binary_logloss: 12.9355 + 6.37914
# [2984]	cv_agg's auc: 0.68851 + 0.155924	cv_agg's l1: 0.382707 + 0.168748	cv_agg's binary_logloss: 12.9355 + 6.37913
# [2985]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382707 + 0.168748	cv_agg's binary_logloss: 12.9355 + 6.37912
# [2986]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382707 + 0.168749	cv_agg's binary_logloss: 12.9355 + 6.37909
# [2987]	cv_agg's auc: 0.688511 + 0.155926	cv_agg's l1: 0.382708 + 0.168747	cv_agg's binary_logloss: 12.9355 + 6.37909
# [2988]	cv_agg's auc: 0.688512 + 0.155928	cv_agg's l1: 0.382707 + 0.168748	cv_agg's binary_logloss: 12.9355 + 6.37909
# [2989]	cv_agg's auc: 0.688511 + 0.155926	cv_agg's l1: 0.382707 + 0.168749	cv_agg's binary_logloss: 12.9356 + 6.37907
# [2990]	cv_agg's auc: 0.68851 + 0.155924	cv_agg's l1: 0.382705 + 0.168751	cv_agg's binary_logloss: 12.9356 + 6.37905
# [2991]	cv_agg's auc: 0.68851 + 0.155924	cv_agg's l1: 0.382706 + 0.16875	cv_agg's binary_logloss: 12.9356 + 6.37905
# [2992]	cv_agg's auc: 0.68851 + 0.155925	cv_agg's l1: 0.382707 + 0.168749	cv_agg's binary_logloss: 12.9356 + 6.37905
# [2993]	cv_agg's auc: 0.688511 + 0.155926	cv_agg's l1: 0.382706 + 0.16875	cv_agg's binary_logloss: 12.9356 + 6.37907
# [2994]	cv_agg's auc: 0.688511 + 0.155927	cv_agg's l1: 0.382706 + 0.16875	cv_agg's binary_logloss: 12.9355 + 6.37909
# [2995]	cv_agg's auc: 0.688512 + 0.155928	cv_agg's l1: 0.382706 + 0.168751	cv_agg's binary_logloss: 12.9355 + 6.37911
# [2996]	cv_agg's auc: 0.688512 + 0.155928	cv_agg's l1: 0.382706 + 0.16875	cv_agg's binary_logloss: 12.9355 + 6.37911
# [2997]	cv_agg's auc: 0.688511 + 0.155927	cv_agg's l1: 0.382705 + 0.168753	cv_agg's binary_logloss: 12.9355 + 6.37912
# [2998]	cv_agg's auc: 0.688511 + 0.155926	cv_agg's l1: 0.382704 + 0.168753	cv_agg's binary_logloss: 12.9355 + 6.3791
# [2999]	cv_agg's auc: 0.688511 + 0.155926	cv_agg's l1: 0.382705 + 0.168752	cv_agg's binary_logloss: 12.9355 + 6.37911
# [3000]	cv_agg's auc: 0.688512 + 0.155929	cv_agg's l1: 0.382706 + 0.168751	cv_agg's binary_logloss: 12.9355 + 6.37911
# best n_estimators: 3000
# best cv score: auc-mean 0.9839295335454622
# best cv score: auc-stdv 0.19231984981223677
# best cv score: l1-mean 0.45968552438905874
# best cv score: l1-stdv 0.2007640880994602
# best cv score: binary_logloss-mean 12.935565862182903
# best cv score: binary_logloss-stdv 7.608411466292533
